# %%
# Write "state=maharastra" starting at byte 43
with open('test.txt', 'w') as fp:     # binary write mode
    fp.seek(43)                        # move pointer to byte 43
    d=fp.write("state=maharastra")

# %%
d
# Out:
# 16

# %%
ac=0
nc=0
sp=0

for i in data:
    if i.isalpha():
        ac +=1
    elif i.isdigit():
        nc +=1
    elif not i.isalnum() and not i.isspace():
        sp +=1
print(ac)

lc=data.split('\n')
len(lc)
#line_count = data.count("\n") + 1 if data else 0
# Out:
# 42
# 4

# %%
# Out:
# 5
