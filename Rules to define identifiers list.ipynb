# %%
a = 'harshad'

# %%
print(a)
# Out:
# harshad

# %%
print(a)
# Out:
# harshad

# %%
list:
it is a collection of elements with differnt data types.
it is mutable 
(mutable means changeable/unhashable means we can insert/delete/update in that list
    a = [11,22,33,'asdf',67,'ggh','hjj','gff']
indexing :indexing is only allowed in order data structure
element of list can be access through indexing

forward/positive:
start from 0 and end=-length

reverse/negative:
starts from -1 and ends = -lenght(ends at-len)

It is orderd type data structure(jasi list banvli tashyach order nusar print honar)

# %%
print(a)
# Out:
# [11, 22, 33, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
print(a[])
# Out:
# 11

# %%
data structure:-DS is nothing but a collection of data 
and different data types in particular format(structuring data into particular format)

# %%
emp=[101,'harshad',6547,'harsh@gmail.com','a+','IT']

# %%
emp[3]
# Out:
# 'harsh@gmail.com'

# %%
emp[-5]
# Out:
# 'harshad'

# %%
code should be optimized that why we use reverse indexing

# %%
indexing is only allowed in order data structure
for eg. a=[1,4,3,'harsh',4]
print(a)
    [1,4,3,'harsh',4]
means jya order ne data ahe tyach order ne print hot asel tevhach indexing karata yete kiva allowed aste

# %%
h=[22,56,47,'abc','abc']

# %%
print(h)
# Out:
# [22, 56, 47, 'abc', 'abc']

# %%
h={22,56,47,'abc','abc'}

# %%
print(h)
# Out:
# {56, 'abc', 22, 47}

# %%
*operations on list
insertion:
1.insert
2.append
3.extend
syntax:- insert(index,element)

# %%
a=[11, 22, 33, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
print(a)
# Out:
# [11, 22, 33, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
type(a)
# Out:
# list

# %%
a.insert(3,44)

# %%
print(a)
# Out:
# [11, 22, 33, 44, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
how to find length of list 
syntax:-len.(list name)

# %%
emp=[101,'harshad',6547,'harsh@gmail.com','a+','IT']

# %%
emp
# Out:
# [101, 'harshad', 6547, 'harsh@gmail.com', 'a+', 'IT']

# %%
len(emp)
# Out:
# 6

# %%
*note:-if we try to insert a element into the list but the highest indexing is 6
and we insert the element in 15th(forward) poision then pyhon add that elemnt in last and -15th(reverse)then add that element in first

# %%
emp.insert(15,'python')

# %%
emp
# Out:
# [101, 'harshad', 6547, 'harsh@gmail.com', 'a+', 'IT', 'python']

# %%
emp.insert(-15,'hkp')

# %%
emp
# Out:
# ['hkp', 101, 'harshad', 6547, 'harsh@gmail.com', 'a+', 'IT', 'python']

# %%
* append :- 99% we use append means add element in last
syntax: list_name.append(45)

# %%
emp.append('pune')

# %%
emp
# Out:
# ['hkp', 101, 'harshad', 6547, 'harsh@gmail.com', 'a+', 'IT', 'python', 'pune']

# %%
* extend([]/{}/()):- it is use to insert multiple elements at the end.
multiple -->group-->list/tuple/set

# %%
emp.extend(['a','b','c'])

# %%
print(emp)
# Out:
# ['hkp', 101, 'harshad', 6547, 'harsh@gmail.com', 'a+', 'IT', 'python', 'pune', 'a', 'b', 'c', 'a', 'b', 'c']

# %%
for eg:- 2 list ahet copper and boxite ani aaplyala tyana ekatra karaychay tr aapn
tyana *extend* chy help ne concatinate/connect karu shakto

# %%
copper =['uk','eng','SA','PAK']

# %%
boxite=['gg','gh','sl']

# %%
copper.extend(boxite)

# %%
copper
# Out:
# ['uk', 'eng', 'SA', 'PAK', 'gg', 'gh', 'sl']

# %%
print(copper[-1])
# Out:
# sl

# %%
print(boxite[1])
# Out:
# gh

# %%
print(boxite)
# Out:
# ['gg', 'gh', 'sl']

# %%
append vs extend
* append madhe jevha aapn ek list dyvare multiple element 
pass krto trvha ti list ek perticular element mhanun trit kel jate.

*extend madhe all elements individually add hotat

# %%
copper.append([500,5,6])

# %%
copper
# Out:
# ['uk', 'eng', 'SA', 'PAK', 'gg', 'gh', 'sl', [500, 5, 6], [500, 5, 6]]

# %%
copper.append(['500','5','6'])

# %%
print(copper)
# Out:
# ['uk', 'eng', 'SA', 'PAK', 'gg', 'gh', 'sl', [500, 5, 6], [500, 5, 6], ['500', '5', '6']]

# %%
copper.extend([6,7])

# %%
copper
# Out:
# ['uk',
#  'eng',
#  'SA',
#  'PAK',
#  'gg',
#  'gh',
#  'sl',
#  [500, 5, 6],
#  [500, 5, 6],
#  ['500', '5', '6'],
#  6,
#  7]

# %%
print(copper)
# Out:
# ['uk', 'eng', 'SA', 'PAK', 'gg', 'gh', 'sl', [500, 5, 6], [500, 5, 6], ['500', '5', '6'], 6, 7]

# %%
copper[7][1]
# Out:
# 5

# %%
p=[1,2,3,[533,[111,222,333]]]

# %%
p
# Out:
# [1, 2, 3, [533, [111, 222, 333]]]

# %%
p[3][1][1]
# Out:
# 222

# %%
x=[1,[2,[3,[4,[5]]]]]

# %%
len(x)
# Out:
# 2

# %%
how to identify the indexing of nested list.
*start to count indexing until another open square bracket is not obtained
when open square bracket get then look at to the close square bracket 
and consider this whole small list as element

# %%
n=[1,[2,[3,[4,[5,[6,7,[66,44]]]]]]]

# %%
n
# Out:
# [1, [2, [3, [4, [5, [6, 7, [66, 44]]]]]]]

# %%
len(n)
# Out:
# 2

# %%
n[1][1][1][1][1][1] first[1]1sathi,2nd [1] 3 sathi,3r 1 4sathi,......
# Out:
# 7

# %%
insertion:
n.insert(0,'hkp')

# %%
n
# Out:
# ['hkp', 1, [2, [3, [4, [5, [6, 7, [66, 44]]]]]]]

# %%
*deletion:
1.remove
2.pop
3.clear

# %%
n
# Out:
# ['hkp', 1, [2, [3, [4, [5, [6, 7, [66, 44]]]]]]]

# %%
a=[11, 22, 33, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
a
# Out:
# [11, 22, 33, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
remove(element):-to delete single element using value | name(105 line)
this remove() delete only first occurance element ,
if duplicate values are present in list(eg:-line 107)

# %%
a.remove(11)

# %%
a
# Out:
# [22, 33, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
a=[11, 11,22,22, 33, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
a.remove(11)

# %%
a
# Out:
# [11, 22, 22, 33, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
*pop
*VIMP*it is used for delete specific element,
we don't give specfic index for pop then it is autmatically delete LAST element*(LINE113)
if we want to delete 22 on 3rd index

# %%
a.pop(2)
# Out:
# 22

# %%
a
# Out:
# [11, 22, 'asdf', 67, 'ggh', 'hjj', 'gff']

# %%
a.pop()
# Out:
# 'gff'

# %%
a
# Out:
# [11, 22, 'asdf', 67, 'ggh', 'hjj']

# %%
*clear():- it is used for delete all list

# %%
a.clear()

# %%
a
# Out:
# []

# %%
Delete vs clear
